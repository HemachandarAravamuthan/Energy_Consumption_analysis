# %%
# Importing required package
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Loading the data
df1=pd.read_excel(r"C:\\Users\\hp\\Downloads\\bps_2012_report_english.xlsx")
df2=pd.read_excel(r"C:\\Users\\hp\\Downloads\\bps_2013_report_english.xlsx")
df3=pd.read_excel(r"C:\\Users\\hp\\Downloads\\bps_2014_report_english.xlsx")
df4=pd.read_excel(r"C:\\Users\\hp\\Downloads\\bps_2015_report_english.xlsx")
df5=pd.read_excel(r"C:\\Users\\hp\\Downloads\\bps_2016_report_english.xlsx")
df6=pd.read_excel(r"C:\\Users\\hp\\Downloads\\2017_energy_consumption.xlsx")
df7=pd.read_excel(r"C:\\Users\\hp\\Downloads\\2018_final_data_set.xlsx")
df8=pd.read_excel(r"C:\\Users\\hp\\Downloads\\2019_final_data_set.xlsx")
df9=pd.read_excel(r"C:\\Users\\hp\\Downloads\\2020_final_data_set.xlsx")
df10=pd.read_excel(r"C:\\Users\\hp\\Downloads\\2021_final_bps_dataset.xlsx")

# %%
#Checking the shape of the dataframes
L=[df1,df2,df3,df4,df5,df6,df7,df8,df9,df10]
for ele in L:
    print(ele.shape)
# Out:
# (17980, 41)
# (17012, 39)
# (17226, 41)
# (17665, 41)
# (17564, 41)
# (16949, 41)
# (16653, 41)
# (17208, 41)
# (16848, 41)
# (15232, 58)

# %%
# Checking the columns
for ele in L:
    print(ele.columns)
# Out:
# Index(['The GJ/m2 column has been updated to address conversion irregularities.',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
#        'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30',
#        'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34',
#        'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38',
#        'Unnamed: 39', 'Unnamed: 40'],
#       dtype='object')
# Index(['The GJ/m2 column has been updated to address conversion irregularities.',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
# ...

# %%
df1.head()
# Out:
#   The GJ/m2 column has been updated to address conversion irregularities.  \
# 0                                                NaN
# 1                                        Sector Name
# 2                                    Public Hospital
# 3                                    Public Hospital
# 4                                    Public Hospital
#
#       Unnamed: 1                              Unnamed: 2  \
# 0            NaN                                     NaN
# 1    Sub Sector                        Organization Name
# 2  Acute/Chronic                      Alexandra Hospital
# 3  Acute/Chronic                      Alexandra Hospital
# 4  Acute/Chronic  Alexandria Glengarry Memorial Hospital
#
#                     Unnamed: 3                                     Unnamed: 4  \
# 0                          NaN                                            NaN
# 1               Operation Name                                 Operation Type
# ...

# %%
# Convering the row to heading
headers = df1.iloc[1]
df1= pd.DataFrame(df1.values[2:], columns=headers)
df1=df1.reset_index(drop=True)

# %%
df1.head()
# Out:
# 1      Sector Name    Sub Sector                        Organization Name  \
# 0  Public Hospital  Acute/Chronic                      Alexandra Hospital
# 1  Public Hospital  Acute/Chronic                      Alexandra Hospital
# 2  Public Hospital  Acute/Chronic  Alexandria Glengarry Memorial Hospital
# 3  Public Hospital  Acute/Chronic  Alexandria Glengarry Memorial Hospital
# 4     School Board   School Board            Algoma District School Board
#
# 1                     Operation Name  \
# 0                 Alexandra Hospital
# 1                 Alexandra Hospital
# 2        Glengarry Memorial Hospital
# 3        Glengarry Memorial Hospital
# 4  Adult Ed - Blind River (WC Eaket)
#
# 1                                 Operation Type               Address  \
# 0          Facilities used for hospital purposes       29 Noxon Street
# 1  Administrative offices and related facilities       29 Noxon Street
# 2          Facilities used for hospital purposes  20260 County Road 43
# ...

# %%
# Convering the row to heading
headers = df2.iloc[1]
df2= pd.DataFrame(df2.values[2:], columns=headers)
df2=df2.reset_index(drop=True)
df2.sample(3)
# Out:
# 1            Sector    Sub Sector           Organization  \
# 13003  Municipality  Municipality       Town of Oakville
# 9700   Municipality  Municipality     Region of Waterloo
# 12887  Municipality  Municipality  Town of New Tecumseth
#
# 1                                Operation  \
# 13003                    Clearview Library
# 9700                      Linwood WTP & PS
# 12887  Alliston Memorial Arena-Arena Floor
#
# 1                                    Operation Type  \
# 13003                              Public libraries
# 9700   Facilities related to the treatment of water
# 12887                          Indoor sports arenas
#
# 1                                   Address      City Postal Code  \
# 13003  1148 Winston Churchill Blvd, Unit 5B  Oakville     L6J 0A3
# 9700                         3881 Manser Rd   Linwood     N0B 2T0
# 12887                        49 Nelson St W  Alliston     L9R 1H1
#
# 1     Total Indoor Space_x Unit of Measure  ... DistrictHeating_Unit  \
# ...

# %%
# Convering the row to heading
headers = df3.iloc[1]
df3= pd.DataFrame(df3.values[2:], columns=headers)
df3=df3.reset_index(drop=True)
df3.sample(3)
# Out:
# 1                                      Sector    Sub Sector  \
# 15811                               Municipal  Municipality
# 1956                                Municipal  Municipality
# 7010   Post-Secondary Educational Institution       College
#
# 1             Organization                                 Operation  \
# 15811     Township of Tiny                 Pump House & Reservoir 22
# 1956   City of Mississauga  Huron Park Community Centre Pool & Arena
# 7010       Lambton College              Suncor Sustainability Centre
#
# 1                                         Operation Type             Address  \
# 15811         Facilities related to the pumping of water  39 Balm Beach Rd W
# 1956   Gyms and indoor courts for playing tennis, bas...  830 Paisley Blvd W
# 7010       Administrative offices and related facilities    1489 London Road
#
# 1             City Postal Code Total Indoor Space_x Unit of Measure  ...  \
# ...

# %%
# Convering the row to heading
headers = df4.iloc[1]
df4= pd.DataFrame(df4.values[2:], columns=headers)
df4=df4.reset_index(drop=True)
df4.sample(3)
# Out:
# 1                                      Sector     SubSector  \
# 11130                            School Board  School Board
# 3171                                Municipal  Municipality
# 10996  Post-Secondary Educational Institution       College
#
# 1                             Organization                    Operation  \
# 11130  Thames Valley District School Board    East Williams Memorial PS
# 3171                       City of Toronto  Greenfield - Longmore Lands
# 10996                    St. Clair College                        SCCCA
#
# 1                         Operation Type               Address         City  \
# 11130                             School   4441 Queen St. RR 1  Ailsa Craig
# 3171                               Other   291 Greenfield  Ave      Toronto
# 10996  Classrooms and related facilities  201 Riverside Dr. W.      Windsor
#
# 1     Postal Code Total Indoor Space_x Unit of Measure  ...  \
# 11130      N0M1A0                 2466   Square meters  ...
# ...

# %%
# Column name
print(df1.columns)
print(df2.columns)
print(df3.columns)
print(df4.columns)
# Out:
# Index(['Sector Name', 'Sub Sector ', 'Organization Name', 'Operation Name',
#        'Operation Type', 'Address', 'City', 'Postal Code', 'Total Floor Area ',
#        'Unit', 'Average Hours per week', 'Annual Flow ', 'Electricity',
#        'Electricity Unit', 'Natural Gas', 'Natural Gas2', 'Fuel Oil 1 & 2',
#        'Fuel Oil 1 & 2 Unit', 'Fuel Oil 4 &6', 'Fuel Oil 4 &6 Unit', 'Propane',
#        'Propane Unit', 'Coal Quantity', 'Coal Unit', 'Wood', 'Wood3',
#        'District Heating', 'District Heating Unit', 'Renewable',
#        'Renewable Emission Factor', 'District Cooling',
#        'District Cooling Unit', 'District Cooling Renewable',
#        'District Cooling Renewable Emission Factor', 'Number of Portables',
#        'Swimming Pools', 'GHG Emissions KG', 'Energy Intensity ekWh_sqft',
#        'Energy Intensity ekWh_mega_litre', 'Energy Intensity GJ_m2',
#        'Energy Intensity GJ_mega_litre'],
#       dtype='object', name=1)
# ...

# %%
# Striping the name to make column names unite
df1.rename(columns=lambda x: x.strip(' Name'),inplace=True)

# %%
# Dealing with column colapsed data
df1.rename(columns=str.lower, inplace=True)
df2.rename(columns=str.lower, inplace=True)
df3.rename(columns=str.lower, inplace=True)
df4.rename(columns=str.lower, inplace=True)
df5.rename(columns=str.lower, inplace=True)
df6.rename(columns=str.lower, inplace=True)
df7.rename(columns=str.lower, inplace=True)
df8.rename(columns=str.lower, inplace=True)
df9.rename(columns=str.lower, inplace=True)
df10.rename(columns=str.lower, inplace=True)

# %%
# Dealing with column colapsed data
df1.rename(columns=lambda x: x.replace(' ','') or x.replace('_',''),inplace=True)
df2.rename(columns=lambda x: x.replace(' ','') or x.replace('_',''),inplace=True)
df3.rename(columns=lambda x: x.replace(' ','') or x.replace('_',''),inplace=True)
df4.rename(columns=lambda x: x.replace(' ','') or x.replace('_',''),inplace=True)
df5.rename(columns=lambda x: x.replace(' ','') or x.replace('_',''),inplace=True)
df6.rename(columns=lambda x: x.replace(' ','') or x.replace('_',''),inplace=True)
df7.rename(columns=lambda x: x.replace(' ','') or x.replace('_',''),inplace=True)
df8.rename(columns=lambda x: x.replace(' ','') or x.replace('_',''),inplace=True)
df9.rename(columns=lambda x: x.replace(' ','') or x.replace('_',''),inplace=True)
df10.rename(columns=lambda x: x.replace(' ','') or x.replace('_',''),inplace=True)

# %%
# Values changing
df1.rename(columns = {'operationtyp':'operationtype','postalcod':'postalcode','totalfloorar':'totalfloorarea'}, inplace = True)

# %%
# Concating the dataframe to single dataframe
frames=[df1,df2,df3,df4,df5,df6,df7,df8,df9,df10]
df=pd.concat(frames)

# %%
df1.columns
# Out:
# Index(['sector', 'subsector', 'organization', 'operation', 'operationtype',
#        'address', 'city', 'postalcode', 'totalfloorarea', 'unit',
#        'averagehoursperweek', 'annualflow', 'electricity', 'electricityunit',
#        'turalgas', 'turalgas2', 'fueloil1&2', 'fueloil1&2unit', 'fueloil4&6',
#        'fueloil4&6unit', 'propan', 'propaneunit', 'coalquantity', 'coalunit',
#        'wood', 'wood3', 'districtheating', 'districtheatingunit', 'renewabl',
#        'renewableemissionfactor', 'districtcooling', 'districtcoolingunit',
#        'districtcoolingrenewabl', 'districtcoolingrenewableemissionfactor',
#        'umberofportables', 'swimmingpools', 'ghgemissionskg',
#        'energyintensityekwhsqft', 'energyintensityekwhmegalitr',
#        'energyintensitygjm2', 'energyintensitygjmegalitr'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['sector', 'subsector', 'organization', 'operation', 'operationtype',
#        'address', 'city', 'postalcode', 'totalindoorspacex', 'unitofmeasure',
#        'weeklyaveragehours', 'annualflow(m', 'numberofportables',
#        'swimmingpool', 'electricityquantity', 'electricityunit',
#        'naturalgasquantity', 'naturalgasunit', 'fueloil12quantity',
#        'fueloil12unit', 'fueloil46quantity', 'fueloil46unit',
#        'propanequantity', 'propaneunit', 'coalquantity', 'coalunit',
#        'woodquantity', 'woodunit', 'districtheatingquantity',
#        'districtheatingunit', 'districtheatingisrenewable',
#        'districtcoolingquantity', 'districtcoolingunit',
#        'districtcoolingisrenewable', 'ghgemissionskg',
#        'energyintensityekwhsqft', 'energyintensityekwhmegalitre',
#        'energyintensitygjm2', 'energyintensitygjmegalitre'],
#       dtype='object', name=1)

# %%
df.head()
# Out:
#             sector      subsector                            organization  \
# 0  Public Hospital  Acute/Chronic                      Alexandra Hospital
# 1  Public Hospital  Acute/Chronic                      Alexandra Hospital
# 2  Public Hospital  Acute/Chronic  Alexandria Glengarry Memorial Hospital
# 3  Public Hospital  Acute/Chronic  Alexandria Glengarry Memorial Hospital
# 4     School Board   School Board            Algoma District School Board
#
#                            operation  \
# 0                 Alexandra Hospital
# 1                 Alexandra Hospital
# 2        Glengarry Memorial Hospital
# 3        Glengarry Memorial Hospital
# 4  Adult Ed - Blind River (WC Eaket)
#
#                                    operationtype               address  \
# 0          Facilities used for hospital purposes       29 Noxon Street
# 1  Administrative offices and related facilities       29 Noxon Street
# 2          Facilities used for hospital purposes  20260 County Road 43
# ...

# %%
for i in df.columns:
    print(i)
# Out:
# sector
# subsector
# organization
# operation
# operationtype
# address
# city
# postalcode
# totalfloorarea
# unit
# averagehoursperweek
# annualflow
# electricity
# electricityunit
# turalgas
# turalgas2
# fueloil1&2
# fueloil1&2unit
# fueloil4&6
# fueloil4&6unit
# propan
# propaneunit
# coalquantity
# coalunit
# wood
# wood3
# districtheating
# districtheatingunit
# renewabl
# renewableemissionfactor
# districtcooling
# districtcoolingunit
# districtcoolingrenewabl
# districtcoolingrenewableemissionfactor
# umberofportables
# swimmingpools
# ghgemissionskg
# energyintensityekwhsqft
# energyintensityekwhmegalitr
# energyintensitygjm2
# energyintensitygjmegalitr
# totalindoorspacex
# unitofmeasure
# weeklyaveragehours
# annualflow(m
# numberofportables
# swimmingpool
# electricityquantity
# naturalgasquantity
# naturalgasunit
# fueloil12quantity
# fueloil12unit
# fueloil46quantity
# fueloil46unit
# propanequantity
# woodquantity
# woodunit
# districtheatingquantity
# ...

# %%
for i in df.columns:
    print(i,df[i].isna().sum())
# Out:
# sector 0
# subsector 5
# organization 0
# operation 15232
# operationtype 15232
# address 107
# city 1
# postalcode 180
# totalfloorarea 152351
# unit 153324
# averagehoursperweek 152351
# annualflow 152351
# electricity 152351
# electricityunit 17667
# turalgas 152351
# turalgas2 152351
# fueloil1&2 152351
# fueloil1&2unit 152351
# fueloil4&6 152351
# fueloil4&6unit 152351
# propan 152351
# propaneunit 145465
# coalquantity 15893
# coalunit 152350
# wood 152351
# wood3 152351
# districtheating 152351
# districtheatingunit 151145
# renewabl 152351
# renewableemissionfactor 152351
# districtcooling 152351
# districtcoolingunit 151505
# districtcoolingrenewabl 152351
# districtcoolingrenewableemissionfactor 32967
# umberofportables 152351
# swimmingpools 152351
# ghgemissionskg 15265
# energyintensityekwhsqft 15234
# energyintensityekwhmegalitr 152351
# energyintensitygjm2 20650
# energyintensitygjmegalitr 152351
# totalindoorspacex 33210
# unitofmeasure 39045
# ...

# %%
cols=['sector','subsector','organization','operation','operationtype','address',
      'city','postalcode','coalquantity','ghgemissionskg','energyintensityekwhsqft']
new_df=df[cols]

# %%
new_df.head()
# Out:
#             sector      subsector                            organization  \
# 0  Public Hospital  Acute/Chronic                      Alexandra Hospital
# 1  Public Hospital  Acute/Chronic                      Alexandra Hospital
# 2  Public Hospital  Acute/Chronic  Alexandria Glengarry Memorial Hospital
# 3  Public Hospital  Acute/Chronic  Alexandria Glengarry Memorial Hospital
# 4     School Board   School Board            Algoma District School Board
#
#                            operation  \
# 0                 Alexandra Hospital
# 1                 Alexandra Hospital
# 2        Glengarry Memorial Hospital
# 3        Glengarry Memorial Hospital
# 4  Adult Ed - Blind River (WC Eaket)
#
#                                    operationtype               address  \
# 0          Facilities used for hospital purposes       29 Noxon Street
# 1  Administrative offices and related facilities       29 Noxon Street
# 2          Facilities used for hospital purposes  20260 County Road 43
# ...

# %%
new_df.shape
# Out:
# (154234, 11)

# %%
new_df.isna().sum()
# Out:
# sector                         0
# subsector                      5
# organization                   0
# operation                  15232
# operationtype              15232
# address                      107
# city                           1
# postalcode                   180
# coalquantity               15893
# ghgemissionskg             15265
# energyintensityekwhsqft    15234
# dtype: int64

# %%
new_df=new_df.dropna()

# %%
new_df.isna().sum()
# Out:
# sector                     0
# subsector                  0
# organization               0
# operation                  0
# operationtype              0
# address                    0
# city                       0
# postalcode                 0
# coalquantity               0
# ghgemissionskg             0
# energyintensityekwhsqft    0
# dtype: int64

# %%
new_df.nunique()
# Out:
# sector                          9
# subsector                      16
# organization                  763
# operation                   25607
# operationtype                  36
# address                     23491
# city                         1545
# postalcode                  20494
# coalquantity                   13
# ghgemissionskg             153056
# energyintensityekwhsqft    137052
# dtype: int64

# %%
new_df['sector'].value_counts()
# Out:
# sector
# municipal                                 87868
# school board                              44700
# municipality                              10794
# post-secondary educational institution     6451
# public hospital                            3226
# post-secondary institution                  756
# hospital                                    439
# Name: count, dtype: int64

# %%
new_df['sector']=new_df['sector'].str.lower()
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_41900\3729870986.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['sector']=new_df['sector'].str.lower()

# %%
new_df['sector'].value_counts()
# Out:
# sector
# municipal                                 98486
# school board                              44700
# municipality                              10805
# post-secondary educational institution     6463
# school boards                              4851
# public hospital                            3489
# post-secondary institution                  756
# hospital                                    439
# postsecondary                               340
# Name: count, dtype: int64

# %%
new_df.to_csv('ghg.csv',index=False)
